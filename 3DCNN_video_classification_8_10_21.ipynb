# %%
# !git clone https://github.com/chen0040/keras-video-classifier.git
# Out:
# Cloning into 'keras-video-classifier'...
# remote: Enumerating objects: 705, done.
# remote: Total 705 (delta 0), reused 0 (delta 0), pack-reused 705
# Receiving objects: 100% (705/705), 235.41 MiB | 25.09 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
#for installing rar file
# !pip install pyunpack
# !pip install patool
# Out:
# ...
#      |████████████████████████████████| 77 kB 2.9 MB/s
# ...

# %%
# %cd /content/keras-video-classifier/demo/very_large_data
# Out:
# /content/keras-video-classifier/demo/very_large_data

# %%
# !wget --no-check-certificate "https://www.crcv.ucf.edu/data/UCF101/UCF101.rar"
# !unrar x UCF101.rar -inul -y
# !rm *.rar
# Out:
# --2021-10-08 14:44:54--  https://www.crcv.ucf.edu/data/UCF101/UCF101.rar
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6932971618 (6.5G) [application/rar]
# Saving to: ‘UCF101.rar’
#
# UCF101.rar          100%[===================>]   6.46G  15.7MB/s    in 7m 7s
#
# 2021-10-08 14:52:03 (15.5 MB/s) - ‘UCF101.rar’ saved [6932971618/6932971618]

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Rowing"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/Skijet'

# %%
#CREATE DATASET
import os
import numpy as np
import cv2
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
#import keras_metrics as km
from tensorflow.python.keras.metrics import Metric
 
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
import cv2
import os
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array



classes = ["Biking", "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
X = []
Y = []

height = 16
width  = 16
depth = 50
color = True
skip = True

input_dir = "/content/video_data"

classes_list = os.listdir(input_dir)

for c in classes_list:
  print(c)
  files_list = os.listdir(os.path.join(input_dir, c))
  for f in files_list:
    print(f)
    filename = "/content/video_data/" + c + "/" + f
    cap = cv2.VideoCapture(filename)
    nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    if skip:
        frames = [x * nframe / depth for x in range(depth)]
    else:
        frames = [x for x in range(depth)]
    framearray = []

    for i in range(depth):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
        ret, frame = cap.read()
        frame = cv2.resize(frame, (height, width))
        if color:
            framearray.append(frame)
        else:
            framearray.append(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

    cap.release()
    X.append(framearray)
    y = [0]*len(classes)
    y[classes.index(c)] = 1
    Y.append(y)

X = np.asarray(X)
Y = np.asarray(Y)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=0)
# Out:
# Rowing
# v_Rowing_g24_c02.avi
# v_Rowing_g19_c02.avi
# v_Rowing_g13_c07.avi
# v_Rowing_g25_c04.avi
# v_Rowing_g01_c03.avi
# v_Rowing_g20_c04.avi
# v_Rowing_g12_c04.avi
# v_Rowing_g06_c01.avi
# v_Rowing_g14_c07.avi
# v_Rowing_g16_c03.avi
# v_Rowing_g07_c04.avi
# v_Rowing_g10_c07.avi
# v_Rowing_g02_c03.avi
# v_Rowing_g10_c02.avi
# v_Rowing_g04_c05.avi
# v_Rowing_g13_c02.avi
# v_Rowing_g24_c03.avi
# v_Rowing_g15_c07.avi
# v_Rowing_g02_c01.avi
# v_Rowing_g08_c02.avi
# v_Rowing_g07_c03.avi
# v_Rowing_g13_c03.avi
# v_Rowing_g15_c04.avi
# v_Rowing_g22_c04.avi
# v_Rowing_g12_c02.avi
# v_Rowing_g10_c04.avi
# v_Rowing_g13_c01.avi
# v_Rowing_g01_c01.avi
# v_Rowing_g05_c02.avi
# v_Rowing_g08_c03.avi
# v_Rowing_g03_c06.avi
# v_Rowing_g24_c01.avi
# v_Rowing_g18_c01.avi
# v_Rowing_g02_c04.avi
# v_Rowing_g12_c05.avi
# v_Rowing_g15_c03.avi
# v_Rowing_g19_c05.avi
# v_Rowing_g12_c03.avi
# v_Rowing_g07_c01.avi
# v_Rowing_g19_c03.avi
# v_Rowing_g24_c04.avi
# v_Rowing_g22_c01.avi
# v_Rowing_g04_c03.avi
# ...

# %%
#CREATE DATASET FOR VGG16
import os
import numpy as np
import cv2
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
#import keras_metrics as km
from tensorflow.python.keras.metrics import Metric
 
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
import cv2
import os
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array


model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))

classes = ["Biking", "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
X = []
Y = []

height = 224
width  = 224
depth = 50
color = True
skip = True

input_dir = "/content/video_data"

classes_list = os.listdir(input_dir)

for c in classes_list:
  print(c)
  files_list = os.listdir(os.path.join(input_dir, c))
  for f in files_list:
    print(f)
    filename = "/content/video_data/" + c + "/" + f
    cap = cv2.VideoCapture(filename)
    nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    if skip:
        frames = [x * nframe / depth for x in range(depth)]
    else:
        frames = [x for x in range(depth)]
    framearray = []

    for i in range(depth):
        cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
        ret, frame = cap.read()
        frame = cv2.resize(frame, (224, 224), interpolation=cv2.INTER_AREA)

        if color:
            
            input = img_to_array(frame)
            input = np.expand_dims(input, axis=0)
            input = preprocess_input(input)
            feature = model.predict(input).ravel()
            framearray.append(feature)

        else:
            framearray.append(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

    cap.release()
    X.append(framearray)
    y = [0]*len(classes)
    y[classes.index(c)] = 1
    Y.append(y)

X = np.asarray(X)
Y = np.asarray(Y)

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=0)
# Out:
# Rowing
# v_Rowing_g24_c02.avi
# v_Rowing_g19_c02.avi
# v_Rowing_g13_c07.avi
# v_Rowing_g25_c04.avi
# v_Rowing_g01_c03.avi
# v_Rowing_g20_c04.avi
# v_Rowing_g12_c04.avi
# v_Rowing_g06_c01.avi
# v_Rowing_g14_c07.avi
# v_Rowing_g16_c03.avi
# v_Rowing_g07_c04.avi
# v_Rowing_g10_c07.avi
# v_Rowing_g02_c03.avi
# v_Rowing_g10_c02.avi
# v_Rowing_g04_c05.avi
# v_Rowing_g13_c02.avi
# v_Rowing_g24_c03.avi
# v_Rowing_g15_c07.avi
# v_Rowing_g02_c01.avi
# v_Rowing_g08_c02.avi
# v_Rowing_g07_c03.avi
# v_Rowing_g13_c03.avi
# v_Rowing_g15_c04.avi
# v_Rowing_g22_c04.avi
# v_Rowing_g12_c02.avi
# v_Rowing_g10_c04.avi
# v_Rowing_g13_c01.avi
# v_Rowing_g01_c01.avi
# v_Rowing_g05_c02.avi
# v_Rowing_g08_c03.avi
# v_Rowing_g03_c06.avi
# v_Rowing_g24_c01.avi
# v_Rowing_g18_c01.avi
# v_Rowing_g02_c04.avi
# v_Rowing_g12_c05.avi
# v_Rowing_g15_c03.avi
# v_Rowing_g19_c05.avi
# v_Rowing_g12_c03.avi
# v_Rowing_g07_c01.avi
# v_Rowing_g19_c03.avi
# v_Rowing_g24_c04.avi
# v_Rowing_g22_c01.avi
# v_Rowing_g04_c03.avi
# ...

# %%
X.shape[1:]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-65-93c57cd5b930> in <module>()
# ----> 1 X.shape[1:]
#
# AttributeError: 'list' object has no attribute 'shape'

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (716, 50, 16, 16, 3)
# (179, 50, 16, 16, 3)

# %%
#Training Session of 3DCNN
import os

import matplotlib
#matplotlib.use('AGG')
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D)
from keras.layers.advanced_activations import LeakyReLU
from keras.losses import categorical_crossentropy
from keras.models import Sequential
#from keras.optimizers import Adam
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split


model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    X.shape[1:]), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(32, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

model.compile(loss=categorical_crossentropy,
              optimizer='Adam', metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=4,
                    epochs=10, verbose=1, shuffle=True)
# Out:
# Model: "sequential_10"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv3d_24 (Conv3D)           (None, 50, 16, 16, 32)    2624
# _________________________________________________________________
# activation_23 (Activation)   (None, 50, 16, 16, 32)    0
# _________________________________________________________________
# conv3d_25 (Conv3D)           (None, 50, 16, 16, 32)    27680
# _________________________________________________________________
# activation_24 (Activation)   (None, 50, 16, 16, 32)    0
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 17, 6, 6, 32)      0
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 17, 6, 6, 32)      0
# _________________________________________________________________
# conv3d_26 (Conv3D)           (None, 17, 6, 6, 64)      55360
# ...

# %%
#ENSEMBLE CLASSIFIER of 3DCNN
input_shape = (50, 16, 16, 3)
nb_classes = 7
def create_3dcnn(input_shape, nb_classes):
    model = Sequential()
    model.add(Conv3D(32, kernel_size=(3,3,3), input_shape=(
        input_shape), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(32, kernel_size=(3,3,3), padding='same'))
    model.add(Activation('softmax'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
    model.add(Activation('relu'))
    model.add(Conv3D(64, kernel_size=(3,3,3), padding='same'))
    model.add(Activation('softmax'))
    model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(512, activation='sigmoid'))
    model.add(Dropout(0.5))
    model.add(Dense(nb_classes, activation='softmax'))

    return model

models=[]
for i in range(3):
  print('model{}:'.format(i))
  models.append(create_3dcnn(X.shape[1:], nb_classes))
  models[-1].compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
  history = models[-1].fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=4, epochs=10, verbose=1, shuffle=True)
  #plot_history(history , args.output, i)
  #save_history(history, args.output, i)
# Out:
# model0:
# Epoch 1/10
# 179/179 [==============================] - 132s 735ms/step - loss: 2.1883 - accuracy: 0.1578 - val_loss: 1.9973 - val_accuracy: 0.1564
# Epoch 2/10
# 179/179 [==============================] - 131s 734ms/step - loss: 2.1436 - accuracy: 0.1480 - val_loss: 1.9876 - val_accuracy: 0.1564
# Epoch 3/10
# 179/179 [==============================] - 131s 731ms/step - loss: 2.0952 - accuracy: 0.1522 - val_loss: 2.0062 - val_accuracy: 0.1564
# Epoch 4/10
# 179/179 [==============================] - 131s 731ms/step - loss: 2.0577 - accuracy: 0.1494 - val_loss: 2.0398 - val_accuracy: 0.1508
# Epoch 5/10
# 179/179 [==============================] - 131s 729ms/step - loss: 1.9427 - accuracy: 0.1816 - val_loss: 1.9409 - val_accuracy: 0.1564
# Epoch 6/10
# 179/179 [==============================] - 131s 730ms/step - loss: 1.9264 - accuracy: 0.1676 - val_loss: 1.8738 - val_accuracy: 0.2123
# Epoch 7/10
# ...

# %%
#CREATE DATASET for Query Video
import os
import numpy as np
import cv2
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
#import keras_metrics as km
from tensorflow.python.keras.metrics import Metric
 
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
import cv2
import os
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array



classes = ["Biking"]#, "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
X = []
Y = []

height = 16
width  = 16
depth = 50
color = True
skip = True

input_dir = "/content/Query"

classes_list = os.listdir(input_dir)

for c in classes_list:
  print(c)
  files_list = os.listdir(os.path.join(input_dir, c))
  for f in files_list:
    if (f != '.ipynb_checkpoints'):
      print(f)
      filename = "/content/Query/" + c + "/" + f
      cap = cv2.VideoCapture(filename)
      nframe = cap.get(cv2.CAP_PROP_FRAME_COUNT)
      if skip:
          frames = [x * nframe / depth for x in range(depth)]
      else:
          frames = [x for x in range(depth)]
      framearray = []

      for i in range(depth):
          cap.set(cv2.CAP_PROP_POS_FRAMES, frames[i])
          ret, frame = cap.read()
          frame = cv2.resize(frame, (height, width))
          if color:
              framearray.append(frame)
          else:
              framearray.append(cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY))

      cap.release()
      X.append(framearray)
      #y = [0]*len(classes)
    #y[classes.index(c)] = 1
    #Y.append(y)

X = np.asarray(X)
#Y = np.asarray(Y)
# Out:
# Biking
# v_Biking_g01_c01.avi
# .ipynb_checkpoints

# %%
import numpy as np

#for i in range(3):
  #print('model{}:'.format(i))
  #models.append(create_3dcnn(X.shape[1:], nb_classes))
  #models[-1].compile(loss='categorical_crossentropy',optimizer='adam', metrics=['accuracy'])
  #history = models[-1].fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=4, epochs=10, verbose=1, shuffle=True)
  #print(models[i].predict(X))

finalpred=(models[0].predict(X)+ models[1].predict(X) + models[2].predict(X))/3

print(finalpred)
# Out:
# [[0.33140886 0.07611613 0.24518687 0.08483401 0.10257629 0.06972706
#   0.09015078]]

# %%
X.shape
# Out:
# (1, 50, 16, 16, 3)

# %%
#3DCNN with batch normalization
import os

import matplotlib
#matplotlib.use('AGG')
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D, BatchNormalization)
from keras.layers.advanced_activations import LeakyReLUfrom keras.losses import categorical_crossentropy
from keras.models import Sequential
#from keras.optimizers import Adam
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split


model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    X.shape[1:]), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(32, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv3D(64, kernel_size=(3, 3, 3), padding='same'))
model.add(Activation('softmax'))
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding='same'))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='sigmoid'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))

model.compile(loss=categorical_crossentropy,
              optimizer='rmsprop', metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=4,
                    epochs=10, verbose=1, shuffle=True)

# %%
#3DCNN with batch normalization and LeakyReLU
import os

import matplotlib
#matplotlib.use('AGG')
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import cifar10
from keras.layers import (Activation, Conv3D, Dense, Dropout, Flatten,
                          MaxPooling3D, BatchNormalization)
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
#from keras.optimizers import Adam
from keras.utils import np_utils
from keras.utils.vis_utils import plot_model
from sklearn.model_selection import train_test_split


model = Sequential()
model.add(Conv3D(32, kernel_size=(3, 3, 3), input_shape=(
    X.shape[1:]), padding="same"))
model.add(LeakyReLU())
model.add(Conv3D(32, padding="same", kernel_size=(3, 3, 3)))
model.add(LeakyReLU())
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
model.add(Dropout(0.25))

model.add(Conv3D(64, padding="same", kernel_size=(3, 3, 3)))
model.add(LeakyReLU())
model.add(Conv3D(64, padding="same", kernel_size=(3, 3, 3)))
model.add(LeakyReLU())
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
model.add(Dropout(0.25))

model.add(Conv3D(64, padding="same", kernel_size=(3, 3, 3)))
model.add(LeakyReLU())
model.add(Conv3D(64, padding="same", kernel_size=(3, 3, 3)))
model.add(LeakyReLU())
model.add(MaxPooling3D(pool_size=(3, 3, 3), padding="same"))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(7, activation='softmax'))
model.compile(loss=categorical_crossentropy,
              optimizer='rmsprop', metrics=['accuracy'])
model.summary()

history = model.fit(X_train, y_train, validation_data=(X_test, y_test), batch_size=4,
                    epochs=10, verbose=1, shuffle=True)

# %%
#!git clone https://github.com/kcct-fujimotolab/3DCNN
