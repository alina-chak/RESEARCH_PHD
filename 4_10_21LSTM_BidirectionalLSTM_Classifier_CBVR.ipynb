# %%
# !git clone https://github.com/chen0040/keras-video-classifier.git
# Out:
# Cloning into 'keras-video-classifier'...
# remote: Enumerating objects: 705, done.
# remote: Total 705 (delta 0), reused 0 (delta 0), pack-reused 705
# Receiving objects: 100% (705/705), 235.41 MiB | 30.36 MiB/s, done.
# Resolving deltas: 100% (345/345), done.

# %%
# %cd /content/keras-video-classifier
# Out:
# /content/keras-video-classifier

# %%
import urllib.request
import os
import sys
import patoolib

URL_LINK = 'http://crcv.ucf.edu/data/UCF101/UCF101.rar'


def reporthook(block_num, block_size, total_size):
    read_so_far = block_num * block_size
    if total_size > 0:
        percent = read_so_far * 1e2 / total_size
        s = "\r%5.1f%% %*d / %d" % (
            percent, len(str(total_size)), read_so_far, total_size)
        sys.stderr.write(s)
        if read_so_far >= total_size:  # near the end
            sys.stderr.write("\n")
    else:  # total size is unknown
        sys.stderr.write("read %d\n" % (read_so_far,))


def download_ucf(data_dir_path):
    ucf_rar = data_dir_path + '/UCF101.rar'

    if not os.path.exists(data_dir_path):
        os.makedirs(data_dir_path)

    if not os.path.exists(ucf_rar):
        print('ucf file does not exist, downloading from internet')
        urllib.request.urlretrieve(url=URL_LINK, filename=ucf_rar,
                                   reporthook=reporthook)

    print('unzipping ucf file')
    patoolib.extract_archive(ucf_rar, outdir=data_dir_path)


def scan_ucf(data_dir_path, limit):
    input_data_dir_path = data_dir_path + '/UCF-101'

    result = dict()

    dir_count = 0
    for f in os.listdir(input_data_dir_path):
        file_path = input_data_dir_path + os.path.sep + f
        if not os.path.isfile(file_path):
            dir_count += 1
            for ff in os.listdir(file_path):
                video_file_path = file_path + os.path.sep + ff
                result[video_file_path] = f
        if dir_count == limit:
            break
    return result


def scan_ucf_with_labels(data_dir_path, labels):
    input_data_dir_path = data_dir_path + '/UCF-101'

    result = dict()

    dir_count = 0
    for label in labels:
        file_path = input_data_dir_path + os.path.sep + label
        if not os.path.isfile(file_path):
            dir_count += 1
            for ff in os.listdir(file_path):
                video_file_path = file_path + os.path.sep + ff
                result[video_file_path] = label
    return result



def load_ucf(data_dir_path):
    UFC101_data_dir_path = data_dir_path + "/UCF-101"
    if not os.path.exists(UFC101_data_dir_path):
        download_ucf(data_dir_path)


def main():
    data_dir_path = '/content/keras-video-classifier/demo/very_large_data'
    load_ucf(data_dir_path)


if __name__ == '__main__':
    main()

# %%
#for installing rar file
# !pip install pyunpack
# !pip install patool
# Out:
# Collecting pyunpack
#   Downloading pyunpack-0.2.2-py2.py3-none-any.whl (3.8 kB)
# Collecting entrypoint2
#   Downloading entrypoint2-0.2.4-py3-none-any.whl (6.2 kB)
# Collecting easyprocess
#   Downloading EasyProcess-0.3-py2.py3-none-any.whl (7.9 kB)
# Installing collected packages: entrypoint2, easyprocess, pyunpack
# Successfully installed easyprocess-0.3 entrypoint2-0.2.4 pyunpack-0.2.2
# Collecting patool
#   Downloading patool-1.12-py2.py3-none-any.whl (77 kB)
#      |████████████████████████████████| 77 kB 3.3 MB/s
# Installing collected packages: patool
# Successfully installed patool-1.12

# %%
import urllib.request
import os
import sys
import patoolib

URL_LINK = 'http://crcv.ucf.edu/data/UCF101/UCF101.rar'


def reporthook(block_num, block_size, total_size):
    read_so_far = block_num * block_size
    if total_size > 0:
        percent = read_so_far * 1e2 / total_size
        s = "\r%5.1f%% %*d / %d" % (
            percent, len(str(total_size)), read_so_far, total_size)
        sys.stderr.write(s)
        if read_so_far >= total_size:  # near the end
            sys.stderr.write("\n")
    else:  # total size is unknown
        sys.stderr.write("read %d\n" % (read_so_far,))


def download_ucf(data_dir_path):
    ucf_rar = data_dir_path + '/UCF101.rar'

    if not os.path.exists(data_dir_path):
        os.makedirs(data_dir_path)

    if not os.path.exists(ucf_rar):
        print('ucf file does not exist, downloading from internet')
        urllib.request.urlretrieve(url=URL_LINK, filename=ucf_rar, reporthook=reporthook)
                                   

    print('unzipping ucf file')
    patoolib.extract_archive(ucf_rar, outdir=data_dir_path)


def scan_ucf(data_dir_path, limit):
    input_data_dir_path = data_dir_path + '/UCF-101'

    result = dict()

    dir_count = 0
    for f in os.listdir(input_data_dir_path):
        file_path = input_data_dir_path + os.path.sep + f
        if not os.path.isfile(file_path):
            dir_count += 1
            for ff in os.listdir(file_path):
                video_file_path = file_path + os.path.sep + ff
                result[video_file_path] = f
        if dir_count == limit:
            break
    return result


def scan_ucf_with_labels(data_dir_path, labels):
    input_data_dir_path = data_dir_path + '/UCF-101'

    result = dict()

    dir_count = 0
    for label in labels:
        file_path = input_data_dir_path + os.path.sep + label
        if not os.path.isfile(file_path):
            dir_count += 1
            for ff in os.listdir(file_path):
                video_file_path = file_path + os.path.sep + ff
                result[video_file_path] = label
    return result



def load_ucf(data_dir_path):
    UFC101_data_dir_path = data_dir_path + "/UCF-101"
    if not os.path.exists(UFC101_data_dir_path):
        download_ucf(data_dir_path)


def main():
    data_dir_path = '/content/keras-video-classifier/demo/very_large_data'
    load_ucf(data_dir_path)


if __name__ == '__main__':
    main()
# Out:
# ucf file does not exist, downloading from internet
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-13-3ad78430f7b6> in <module>()
#      82
#      83 if __name__ == '__main__':
# ---> 84     main()
#
# <ipython-input-13-3ad78430f7b6> in main()
#      78 def main():
#      79     data_dir_path = '/content/keras-video-classifier/demo/very_large_data'
# ---> 80     load_ucf(data_dir_path)
#      81
#      82
#
# <ipython-input-13-3ad78430f7b6> in load_ucf(data_dir_path)
#      73     UFC101_data_dir_path = data_dir_path + "/UCF-101"
#      74     if not os.path.exists(UFC101_data_dir_path):
# ---> 75         download_ucf(data_dir_path)
#      76
#      77
#
# <ipython-input-13-3ad78430f7b6> in download_ucf(data_dir_path)
#      28     if not os.path.exists(ucf_rar):
#      29         print('ucf file does not exist, downloading from internet')
# ---> 30         urllib.request.urlretrieve(url=URL_LINK, filename=ucf_rar, reporthook=reporthook)
#      31
#      32
#
# /usr/lib/python3.7/urllib/request.py in urlretrieve(url, filename, reporthook, data)
#     245     url_type, path = splittype(url)
#     246
# --> 247     with contextlib.closing(urlopen(url, data)) as fp:
#     248         headers = fp.info()
#     249
#
# /usr/lib/python3.7/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     220     else:
#     221         opener = _opener
# --> 222     return opener.open(url, data, timeout)
#     223
#     224 def install_opener(opener):
#
# /usr/lib/python3.7/urllib/request.py in open(self, fullurl, data, timeout)
#     529         for processor in self.process_response.get(protocol, []):
#     530             meth = getattr(processor, meth_name)
# --> 531             response = meth(req, response)
#     532
#     533         return response
#
# /usr/lib/python3.7/urllib/request.py in http_response(self, request, response)
#     639         if not (200 <= code < 300):
#     640             response = self.parent.error(
# --> 641                 'http', request, response, code, msg, hdrs)
#     642
#     643         return response
#
# /usr/lib/python3.7/urllib/request.py in error(self, proto, *args)
#     567         if http_err:
#     568             args = (dict, 'default', 'http_error_default') + orig_args
# --> 569             return self._call_chain(*args)
#     570
#     571 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.7/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     501         for handler in handlers:
#     502             func = getattr(handler, meth_name)
# --> 503             result = func(*args)
#     504             if result is not None:
#     505                 return result
#
# /usr/lib/python3.7/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     647 class HTTPDefaultErrorHandler(BaseHandler):
#     648     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 649         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     650
#     651 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
# %cd /content/keras-video-classifier/demo/very_large_data
# Out:
# /content/keras-video-classifier/demo/very_large_data

# %%
# !wget --no-check-certificate "https://www.crcv.ucf.edu/data/UCF101/UCF101.rar"
# !unrar x UCF101.rar -inul -y
# !rm *.rar
# Out:
# --2021-10-08 05:42:50--  https://www.crcv.ucf.edu/data/UCF101/UCF101.rar
# Resolving www.crcv.ucf.edu (www.crcv.ucf.edu)... 132.170.214.127
# Connecting to www.crcv.ucf.edu (www.crcv.ucf.edu)|132.170.214.127|:443... connected.
# WARNING: cannot verify www.crcv.ucf.edu's certificate, issued by ‘CN=InCommon RSA Server CA,OU=InCommon,O=Internet2,L=Ann Arbor,ST=MI,C=US’:
#   Unable to locally verify the issuer's authority.
# HTTP request sent, awaiting response... 200 OK
# Length: 6932971618 (6.5G) [application/rar]
# Saving to: ‘UCF101.rar’
#
# UCF101.rar          100%[===================>]   6.46G  41.5MB/s    in 2m 8s
#
# 2021-10-08 05:44:58 (51.7 MB/s) - ‘UCF101.rar’ saved [6932971618/6932971618]

# %%
import os
def scan_ucf_with_labels(data_dir_path, labels):
    input_data_dir_path = data_dir_path + '/UCF-101'

    result = dict()

    dir_count = 0
    for label in labels:
        file_path = input_data_dir_path + os.path.sep + label
        if not os.path.isfile(file_path):
            dir_count += 1
            for ff in os.listdir(file_path):
                video_file_path = file_path + os.path.sep + ff
                result[video_file_path] = label
    return result

# %%
#classes = ["ApplyEyeMakeup", "Archery", "ApplyLipstick", "BabyCrawling", "BalanceBeam", "BandMarching"]
classes = ["Biking", "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
data_dir_path = '/content/keras-video-classifier/demo/very_large_data'
scan_ucf_with_labels(data_dir_path, classes)
# Out:
# {'/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g01_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g01_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g01_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g01_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g02_c07.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g03_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g03_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g03_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g03_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g04_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g04_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g04_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g04_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g04_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g05_c07.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g06_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g06_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g06_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g06_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g06_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g07_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g08_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g09_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g09_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g09_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g09_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g10_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g11_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g12_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g12_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g12_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g12_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g13_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g14_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g14_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g14_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g14_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g15_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g15_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g15_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g15_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g15_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g16_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g16_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g16_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g16_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g16_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g17_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g18_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g19_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g19_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g19_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g19_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g20_c07.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g21_c07.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g22_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g22_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g22_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g22_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g22_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g23_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g23_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g23_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g23_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c05.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c06.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g24_c07.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g25_c01.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g25_c02.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g25_c03.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking/v_Biking_g25_c04.avi': 'Biking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g01_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g02_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g02_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g02_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g02_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g03_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g03_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g03_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g03_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g04_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g04_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g04_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g04_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g05_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g06_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g07_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g07_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g07_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g07_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g07_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g08_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g08_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g08_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g08_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g09_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g10_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g11_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g11_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g11_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g11_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g12_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g12_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g12_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g12_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g13_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g14_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g14_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g14_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g14_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g15_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g15_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g15_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g15_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g16_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g16_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g16_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g16_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g17_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g17_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g17_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g17_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g18_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g18_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g18_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g18_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g19_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g20_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g20_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g20_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g20_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g21_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g21_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g21_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g21_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g22_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g22_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g22_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g22_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g23_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g23_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g23_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g23_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g24_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g24_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g24_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g24_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c01.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c02.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c03.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c04.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c05.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c06.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack/v_JumpingJack_g25_c07.avi': 'JumpingJack',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g01_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g02_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g02_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g02_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g02_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g03_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g03_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g03_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g03_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g04_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g05_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g05_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g05_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g05_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g06_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g07_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g07_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g07_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g07_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g08_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g09_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g10_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g10_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g10_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g10_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g10_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g11_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g12_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g12_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g12_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g12_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g13_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g13_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g13_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g13_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g14_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g14_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g14_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g14_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g15_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g16_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g17_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g18_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g19_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g19_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g19_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g19_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g19_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g20_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g21_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g22_c07.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g23_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c05.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g24_c06.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g25_c01.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g25_c02.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g25_c03.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking/v_Kayaking_g25_c04.avi': 'Kayaking',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c05.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g01_c06.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g02_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g02_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g02_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g02_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c05.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c06.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g03_c07.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c05.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c06.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g04_c07.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g05_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g05_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g05_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g05_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g05_c05.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g06_c01.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g06_c02.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g06_c03.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g06_c04.avi': 'PlayingGuitar',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar/v_PlayingGuitar_g06_c05.avi': 'PlayingGuitar',
# ...
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g12_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g12_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g12_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g13_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g13_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g13_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g13_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g14_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g14_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g14_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g14_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g15_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g15_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g15_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g15_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g16_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g16_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g16_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g16_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g17_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g17_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g17_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g17_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g18_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g18_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g18_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g18_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g19_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g19_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g19_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g19_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g20_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g20_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g20_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g20_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g21_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g21_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g21_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g21_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g22_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g22_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g22_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g22_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g23_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g23_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g23_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g23_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g24_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g24_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g24_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g24_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g25_c01.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g25_c02.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g25_c03.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet/v_Skijet_g25_c04.avi': 'Skijet',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g01_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g01_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g01_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g01_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g02_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g02_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g02_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g02_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g03_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g03_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g03_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g03_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g04_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g04_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g04_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g04_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g05_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g05_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g05_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g05_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g06_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g06_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g06_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g06_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g07_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g07_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g07_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g07_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g08_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g08_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g08_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g08_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g09_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g09_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g09_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g09_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g10_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g10_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g10_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g10_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g11_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g11_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g11_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g11_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g12_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g12_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g12_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g12_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g13_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g13_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g13_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g13_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g14_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g14_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g14_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g14_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g15_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g15_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g15_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g15_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g16_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g16_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g16_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g16_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g17_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g17_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g17_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g17_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g18_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g18_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g18_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g18_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g19_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g19_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g19_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g19_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g20_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g20_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g20_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g20_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g21_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g21_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g21_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g21_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g22_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g22_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g22_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g22_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g23_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g23_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g23_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g23_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g24_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g24_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g24_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g24_c04.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g25_c01.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g25_c02.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g25_c03.avi': 'TaiChi',
#  '/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi/v_TaiChi_g25_c04.avi': 'TaiChi'}

# %%
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
 
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
#import keras_metrics as km
from tensorflow.python.keras.metrics import Metric
 
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
import cv2
import os
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array
from keras.optimizers import SGD

model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


data_dir = "/content/keras-video-classifier/demo/very_large_data"
img_height , img_width = 224, 224
seq_len = 70
 
#classes = ["ApplyEyeMakeup", "Archery", "ApplyLipstick", "BabyCrawling", "BalanceBeam", "BandMarching"] 
classes = ["Biking", "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
#  Creating frames from videos
 
def frames_extraction(video_path):
    frames_list = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
 
    while count <= seq_len: 
         
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
            input = img_to_array(img)
            input = np.expand_dims(input, axis=0)
            input = preprocess_input(input)
            feature = model.predict(input).ravel()
            frames_list.append(image)
            count += 1
        else:
            print("Defected frame")
            break
 
            
    return frames_list
 
def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
          frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
          if len(frames) == seq_len:
            X.append(frames)
          
            y = [0]*len(classes)
            y[classes.index(c)] = 1
            Y.append(y)
     
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y
 
X, Y = create_data(data_dir)
 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=0)
 
model = Sequential()
model.add(ConvLSTM2D(filters = 64, kernel_size = (3, 3), return_sequences = False, data_format = "channels_last", input_shape = (seq_len, img_height, img_width, 3)))
model.add(Dropout(0.2))
model.add(Flatten())
model.add(Dense(256, activation="relu"))
model.add(Dropout(0.3))
model.add(Dense(7, activation = "softmax"))
 
model.summary()


model = Sequential()

model.add(LSTM(units=HIDDEN_UNITS, input_shape=(None, self.num_input_tokens), return_sequences=False, dropout=0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation = "softmax"))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])


#You can try reducing trainable parameters by using some 
#form of Transfer Learning - try freezing the initial few layers and use lower batch sizes.

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/ApplyEyeMakeup"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/ApplyEyeMakeup'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Biking"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Kayaking"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Rowing"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/JumpingJack"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/TaiChi"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/PlayingGuitar"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)

import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Skijet"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/Skijet'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/ApplyLipstick"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/ApplyLipstick'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/Archery"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/Archery'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/BabyCrawling"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/BabyCrawling'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/BalanceBeam"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/BalanceBeam'

# %%
import shutil

source_dir = r"/content/keras-video-classifier/demo/very_large_data/UCF-101/BandMarching"
destination_dir = r"/content/video_data"
shutil.move(source_dir, destination_dir)
# Out:
# '/content/video_data/BandMarching'

# %%
import keras
from keras import applications
from keras.preprocessing.image import ImageDataGenerator
from keras import optimizers
from keras.models import Sequential, Model 
from keras.layers import *
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, TensorBoard, EarlyStopping
 
import os
import cv2
import numpy as np
from sklearn.model_selection import train_test_split
#import keras_metrics as km
from tensorflow.python.keras.metrics import Metric
 
 
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import roc_auc_score
from sklearn.metrics import multilabel_confusion_matrix
import cv2
import os
import numpy as np
from keras.applications.vgg16 import VGG16, preprocess_input
from keras.preprocessing.image import img_to_array
#from keras.optimizers import SGD

model = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


data_dir = "/content/video_data"
img_height , img_width = 224, 224
seq_len = 3
 
#classes = ["ApplyEyeMakeup", "Archery", "ApplyLipstick", "BabyCrawling", "BalanceBeam", "BandMarching"] 
classes = ["Biking", "JumpingJack", "Kayaking", "PlayingGuitar", "Rowing", "Skijet", "TaiChi"]
#  Creating frames from videos
 
def frames_extraction(video_path):
    frames_list = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
 
    while count <= seq_len: 
         
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
            input = img_to_array(image)
            input = np.expand_dims(input, axis=0)
            input = preprocess_input(input)
            feature = model.predict(input).ravel()
            frames_list.append(feature)
            count += 1
        else:
            print("Defected frame")
            break
 
            
    return frames_list
 
def create_data(input_dir):
    X = []
    Y = []
     
    classes_list = os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
          frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
          if len(frames) == seq_len:
            X.append(frames)
          
            y = [0]*len(classes)
            y[classes.index(c)] = 1
            Y.append(y)
     
    X = np.asarray(X)
    Y = np.asarray(Y)
    return X, Y
 
X, Y = create_data(data_dir)
 
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20, shuffle=True, random_state=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# Kayaking
# JumpingJack
# Skijet
# PlayingGuitar
# Rowing
# TaiChi
# Biking

# %%
earlystop = EarlyStopping(patience=7)
callbacks = [earlystop]
 
history = model.fit(x = X_train, y = y_train, epochs=50, batch_size = 4 , shuffle=True, validation_split=0.2, callbacks=callbacks)
#model.fit(x = X_train, y = y_train, epochs=50, batch_size = 4, validation_data=(X_test, y_test)

# %%
print(X_train.shape)
print(X_test.shape)
# Out:
# (716, 3, 1, 7, 7, 512)
# (179, 3, 1, 7, 7, 512)

# %%
#VGG16 Bidirectional LSTM

from keras.layers import Dense, Activation, Dropout, Bidirectional
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
#from keras.optimizers import SGD
from keras import backend as K
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
import os
import numpy as np

model = Sequential()

model.add(LSTM(units=512, input_shape=(3, 25088), return_sequences=False, dropout=0.5))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation = "softmax"))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.summary()

# %%
#Bidirectional LSTM
from keras.layers import Dense, Activation, Dropout, Bidirectional
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
#from keras.optimizers import SGD
from keras import backend as K
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
import os
import numpy as np

model = Sequential()
model.add(Bidirectional(LSTM(units=512, return_sequences=True),
                        input_shape=(3, 25088)))
model.add(Bidirectional(LSTM(10)))
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))

#no of classes
model.add(Dense(7))

model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# bidirectional (Bidirectional (None, 3, 1024)           104861696
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 20)                82800
# _________________________________________________________________
# dense (Dense)                (None, 512)               10752
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 3591
# _________________________________________________________________
# activation (Activation)      (None, 7)                 0
# =================================================================
# Total params: 104,958,839
# Trainable params: 104,958,839
# Non-trainable params: 0
# _________________________________________________________________

# %%
earlystop = EarlyStopping(patience=7)
callbacks = [earlystop]
 
history = model.fit(x = X_train, y = y_train, epochs=50, batch_size = 4 , shuffle=True, validation_split=0.2, callbacks=callbacks)
#model.fit(x = X_train, y = y_train, epochs=50, batch_size = 4, validation_data=(X_test, y_test)
# Out:
# Epoch 1/50
# 143/143 [==============================] - 37s 206ms/step - loss: 1.2829 - accuracy: 0.5245 - val_loss: 0.7590 - val_accuracy: 0.7153
# Epoch 2/50
# 143/143 [==============================] - 28s 197ms/step - loss: 0.4818 - accuracy: 0.8444 - val_loss: 0.3832 - val_accuracy: 0.8542
# Epoch 3/50
# 143/143 [==============================] - 28s 198ms/step - loss: 0.2386 - accuracy: 0.9196 - val_loss: 0.3179 - val_accuracy: 0.9167
# Epoch 4/50
# 143/143 [==============================] - 27s 192ms/step - loss: 0.1497 - accuracy: 0.9510 - val_loss: 0.2565 - val_accuracy: 0.9236
# Epoch 5/50
# 143/143 [==============================] - 28s 198ms/step - loss: 0.0853 - accuracy: 0.9738 - val_loss: 0.2849 - val_accuracy: 0.9167
# Epoch 6/50
# 143/143 [==============================] - 28s 197ms/step - loss: 0.0715 - accuracy: 0.9825 - val_loss: 0.5884 - val_accuracy: 0.8750
# Epoch 7/50
# 143/143 [==============================] - 27s 191ms/step - loss: 0.0417 - accuracy: 0.9878 - val_loss: 0.3009 - val_accuracy: 0.9167
# Epoch 8/50
# 143/143 [==============================] - 27s 191ms/step - loss: 0.0143 - accuracy: 0.9913 - val_loss: 0.3785 - val_accuracy: 0.9375
# Epoch 9/50
# 143/143 [==============================] - 28s 197ms/step - loss: 4.8697e-04 - accuracy: 1.0000 - val_loss: 0.1871 - val_accuracy: 0.9514
# Epoch 10/50
# 143/143 [==============================] - 27s 191ms/step - loss: 0.0016 - accuracy: 0.9983 - val_loss: 0.2242 - val_accuracy: 0.9514
# Epoch 11/50
# 143/143 [==============================] - 27s 191ms/step - loss: 1.0787e-06 - accuracy: 1.0000 - val_loss: 0.2624 - val_accuracy: 0.9653
# Epoch 12/50
# 143/143 [==============================] - 27s 191ms/step - loss: 1.8840e-07 - accuracy: 1.0000 - val_loss: 0.2821 - val_accuracy: 0.9444
# Epoch 13/50
# 143/143 [==============================] - 28s 197ms/step - loss: 4.2724e-08 - accuracy: 1.0000 - val_loss: 0.2795 - val_accuracy: 0.9583
# Epoch 14/50
# 143/143 [==============================] - 28s 196ms/step - loss: 1.6464e-08 - accuracy: 1.0000 - val_loss: 0.2541 - val_accuracy: 0.9444
# Epoch 15/50
# 143/143 [==============================] - 27s 192ms/step - loss: 8.1279e-09 - accuracy: 1.0000 - val_loss: 0.3199 - val_accuracy: 0.9514
# Epoch 16/50
# 143/143 [==============================] - 28s 199ms/step - loss: 6.2522e-09 - accuracy: 1.0000 - val_loss: 0.3206 - val_accuracy: 0.9583

# %%
def frames_extraction(video_path):
    frames_list = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
 
    while count <= seq_len: 
         
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
            input = img_to_array(image)
            input = np.expand_dims(input, axis=0)
            input = preprocess_input(input)
            feature = model.predict(input).ravel()
            frames_list.append(feature)
            count += 1
        else:
            print("Defected frame")
            break
 
            
    return frames_list

seq_len = 3
X = []
file_name = "/content/video_data/Query/q/v_ApplyEyeMakeup_g01_c01.avi"
print(file_name)
frames = frames_extraction(file_name)
if len(frames) == seq_len:
  X.append(frames)
X = np.asarray(X)

X.shape
# Out:
# /content/video_data/Query/q/v_ApplyEyeMakeup_g01_c01.avi
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-163240c00728> in <module>()
#      28 file_name = "/content/video_data/Query/q/v_ApplyEyeMakeup_g01_c01.avi"
#      29 print(file_name)
# ---> 30 frames = frames_extraction(file_name)
#      31 if len(frames) == seq_len:
#      32   X.append(frames)
#
# <ipython-input-43-163240c00728> in frames_extraction(video_path)
#      14             input = np.expand_dims(input, axis=0)
#      15             input = preprocess_input(input)
# ---> 16             feature = model.predict(input).ravel()
#      17             frames_list.append(feature)
#      18             count += 1
#
# /usr/local/lib/python3.7/dist-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1749           for step in data_handler.steps():
#    1750             callbacks.on_predict_batch_begin(step)
# -> 1751             tmp_batch_outputs = self.predict_function(iterator)
#    1752             if data_handler.should_sync:
#    1753               context.async_wait()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     883
#     884       with OptionalXlaContext(self._jit_compile):
# --> 885         result = self._call(*args, **kwds)
#     886
#     887       new_tracing_count = self.experimental_get_tracing_count()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     922       # In this case we have not created variables on the first call. So we can
#     923       # run the first trace but we should fail if variables are created.
# --> 924       results = self._stateful_fn(*args, **kwds)
#     925       if self._created_variables and not ALLOW_DYNAMIC_VARIABLE_CREATION:
#     926         raise ValueError("Creating variables on a non-first call to a function"
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    3036     with self._lock:
#    3037       (graph_function,
# -> 3038        filtered_flat_args) = self._maybe_define_function(args, kwargs)
#    3039     return graph_function._call_flat(
#    3040         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _maybe_define_function(self, args, kwargs)
#    3458               call_context_key in self._function_cache.missed):
#    3459             return self._define_function_with_shape_relaxation(
# -> 3460                 args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3461
#    3462           self._function_cache.missed.add(call_context_key)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _define_function_with_shape_relaxation(self, args, kwargs, flat_args, filtered_flat_args, cache_key_context)
#    3380
#    3381     graph_function = self._create_graph_function(
# -> 3382         args, kwargs, override_flat_arg_shapes=relaxed_arg_shapes)
#    3383     self._function_cache.arg_relaxed[rank_only_cache_key] = graph_function
#    3384
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _create_graph_function(self, args, kwargs, override_flat_arg_shapes)
#    3306             arg_names=arg_names,
#    3307             override_flat_arg_shapes=override_flat_arg_shapes,
# -> 3308             capture_by_value=self._capture_by_value),
#    3309         self._function_attributes,
#    3310         function_spec=self.function_spec,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in func_graph_from_py_func(name, python_func, args, kwargs, signature, func_graph, autograph, autograph_options, add_control_dependencies, arg_names, op_return_value, collections, capture_by_value, override_flat_arg_shapes, acd_record_initial_resource_uses)
#    1005         _, original_func = tf_decorator.unwrap(python_func)
#    1006
# -> 1007       func_outputs = python_func(*func_args, **func_kwargs)
#    1008
#    1009       # invariant: `func_outputs` contains only Tensors, CompositeTensors,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in wrapped_fn(*args, **kwds)
#     666         # the function a weak reference to itself to avoid a reference cycle.
#     667         with OptionalXlaContext(compile_with_xla):
# --> 668           out = weak_wrapped_fn().__wrapped__(*args, **kwds)
#     669         return out
#     670
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/func_graph.py in wrapper(*args, **kwargs)
#     992           except Exception as e:  # pylint:disable=broad-except
#     993             if hasattr(e, "ag_error_metadata"):
# --> 994               raise e.ag_error_metadata.to_exception(e)
#     995             else:
#     996               raise
#
# ValueError: in user code:
#
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1586 predict_function  *
#         return step_function(self, iterator)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1576 step_function  **
#         outputs = model.distribute_strategy.run(run_step, args=(data,))
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:1286 run
#         return self._extended.call_for_each_replica(fn, args=args, kwargs=kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:2849 call_for_each_replica
#         return self._call_for_each_replica(fn, args, kwargs)
#     /usr/local/lib/python3.7/dist-packages/tensorflow/python/distribute/distribute_lib.py:3632 _call_for_each_replica
#         return fn(*args, **kwargs)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1569 run_step  **
#         outputs = model.predict_step(data)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/training.py:1537 predict_step
#         return self(x, training=False)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/base_layer.py:1020 __call__
#         input_spec.assert_input_compatibility(self.input_spec, inputs, self.name)
#     /usr/local/lib/python3.7/dist-packages/keras/engine/input_spec.py:218 assert_input_compatibility
#         str(tuple(shape)))
#
#     ValueError: Input 0 of layer sequential_8 is incompatible with the layer: expected ndim=3, found ndim=4. Full shape received: (None, 224, 224, 3)

# %%
from keras.layers import Dense, Activation, Dropout, Bidirectional
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
#from keras.optimizers import SGD
from keras import backend as K
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
import os
import numpy as np

model1 = VGG16(weights='imagenet', include_top=False, input_shape=(224, 224, 3))


seq_len = 3

data_dir = "/content/video_data/Query"
def frames_extraction(video_path):
    frames_list = []
     
    vidObj = cv2.VideoCapture(video_path)
    # Used as counter variable 
    count = 1
 
    while count <= seq_len: 
         
        success, image = vidObj.read() 
        if success:
            image = cv2.resize(image, (224, 224), interpolation=cv2.INTER_AREA)
            input = img_to_array(image)
            input = np.expand_dims(input, axis=0)
            input = preprocess_input(input)
            feature = model1.predict(input).ravel()
            frames_list.append(feature)

            count += 1
        else:
            print("Defected frame")
            break
 
            
    return frames_list


def create_data(input_dir):
    X = []
    #Y = []
     
    classes_list = os.listdir(input_dir)
     
    for c in classes_list:
        print(c)
        files_list = os.listdir(os.path.join(input_dir, c))
        for f in files_list:
          frames = frames_extraction(os.path.join(os.path.join(input_dir, c), f))
          if len(frames) == seq_len:
            X.append(frames)
          
            #y = [0]*len(classes)
            #y[classes.index(c)] = 1
            #Y.append(y)
     
    X = np.asarray(X)
    #Y = np.asarray(Y)
    return X#, Y
 
X = create_data(data_dir)
# Out:
# q
# .ipynb_checkpoints

# %%
X
# Out:
# array([[[ 0.      ,  0.      ,  0.      , ...,  9.707264,  0.      ,
#          13.597059],
#         [ 0.      ,  0.      ,  0.      , ...,  9.26782 ,  0.      ,
#          14.473428],
#         [ 0.      ,  0.      ,  0.      , ..., 11.065187,  0.      ,
#          16.410591]]], dtype=float32)

# %%
model.predict(X)
# Out:
# array([[1.0000000e+00, 2.7363589e-11, 1.6319804e-14, 1.1355518e-12,
#         5.9626094e-13, 1.3100277e-11]], dtype=float32)

# %%
from keras.layers import Dense, Activation, Dropout, Bidirectional
from keras.layers.recurrent import LSTM
from keras.models import Sequential
from keras.applications.vgg16 import VGG16
from keras.optimizers import SGD
from keras import backend as K
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from keras.callbacks import ModelCheckpoint
import os
import numpy as np

from keras_video_classifier.library.utility.frame_extractors.vgg16_feature_extractor import extract_vgg16_features_live, \
    scan_and_extract_vgg16_features

BATCH_SIZE = 64
NUM_EPOCHS = 20
VERBOSE = 1
HIDDEN_UNITS = 512
MAX_ALLOWED_FRAMES = 20
EMBEDDING_SIZE = 100

K.set_image_dim_ordering('tf')


def generate_batch(x_samples, y_samples):
    num_batches = len(x_samples) // BATCH_SIZE

    while True:
        for batchIdx in range(0, num_batches):
            start = batchIdx * BATCH_SIZE
            end = (batchIdx + 1) * BATCH_SIZE
            yield np.array(x_samples[start:end]), y_samples[start:end]


class VGG16BidirectionalLSTMVideoClassifier(object):
    model_name = 'vgg16-bidirectional-lstm'

    def __init__(self):
        self.num_input_tokens = None
        self.nb_classes = None
        self.labels = None
        self.labels_idx2word = None
        self.model = None
        self.vgg16_model = None
        self.expected_frames = None
        self.vgg16_include_top = True
        self.config = None

    def create_model(self):
        model = Sequential()
        model.add(Bidirectional(LSTM(units=HIDDEN_UNITS, return_sequences=True),
                                input_shape=(self.expected_frames, self.num_input_tokens)))
        model.add(Bidirectional(LSTM(10)))
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.5))

        model.add(Dense(self.nb_classes))

        model.add(Activation('softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

        return model

    @staticmethod
    def get_config_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-config.npy'
        else:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-hi-dim-config.npy'

    @staticmethod
    def get_weight_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-weights.h5'
        else:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-hi-dim-weights.h5'

    @staticmethod
    def get_architecture_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-architecture.json'
        else:
            return model_dir_path + '/' + VGG16BidirectionalLSTMVideoClassifier.model_name + '-hi-dim-architecture.json'

    def load_model(self, config_file_path, weight_file_path):
        if os.path.exists(config_file_path):
            print('loading configuration from ', config_file_path)
        else:
            raise ValueError('cannot locate config file {}'.format(config_file_path))

        config = np.load(config_file_path).item()
        self.num_input_tokens = config['num_input_tokens']
        self.nb_classes = config['nb_classes']
        self.labels = config['labels']
        self.expected_frames = config['expected_frames']
        self.vgg16_include_top = config['vgg16_include_top']
        self.labels_idx2word = dict([(idx, word) for word, idx in self.labels.items()])
        self.config = config

        self.model = self.create_model()
        if os.path.exists(weight_file_path):
            print('loading network weights from ', weight_file_path)
        else:
            raise ValueError('cannot local weight file {}'.format(weight_file_path))

        self.model.load_weights(weight_file_path)

        print('build vgg16 with pre-trained model')
        vgg16_model = VGG16(include_top=self.vgg16_include_top, weights='imagenet')
        vgg16_model.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
        self.vgg16_model = vgg16_model

    def predict(self, video_file_path):
        x = extract_vgg16_features_live(self.vgg16_model, video_file_path)
        frames = x.shape[0]
        if frames > self.expected_frames:
            x = x[0:self.expected_frames, :]
        elif frames < self.expected_frames:
            temp = np.zeros(shape=(self.expected_frames, x.shape[1]))
            temp[0:frames, :] = x
            x = temp
        predicted_class = np.argmax(self.model.predict(np.array([x]))[0])
        predicted_label = self.labels_idx2word[predicted_class]
        return predicted_label

    def fit(self, data_dir_path, model_dir_path, vgg16_include_top=True, data_set_name='UCF-101', test_size=0.3,
            random_state=42):

        self.vgg16_include_top = vgg16_include_top

        config_file_path = self.get_config_file_path(model_dir_path, vgg16_include_top)
        weight_file_path = self.get_weight_file_path(model_dir_path, vgg16_include_top)
        architecture_file_path = self.get_architecture_file_path(model_dir_path, vgg16_include_top)

        self.vgg16_model = VGG16(include_top=self.vgg16_include_top, weights='imagenet')
        self.vgg16_model.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])

        feature_dir_name = data_set_name + '-VGG16-Features'
        if not vgg16_include_top:
            feature_dir_name = data_set_name + '-VGG16-HiDimFeatures'
        max_frames = 0
        self.labels = dict()
        x_samples, y_samples = scan_and_extract_vgg16_features(data_dir_path,
                                                               output_dir_path=feature_dir_name,
                                                               model=self.vgg16_model,
                                                               data_set_name=data_set_name)
        self.num_input_tokens = x_samples[0].shape[1]
        frames_list = []
        for x in x_samples:
            frames = x.shape[0]
            frames_list.append(frames)
            max_frames = max(frames, max_frames)
        self.expected_frames = int(np.mean(frames_list))
        print('max frames: ', max_frames)
        print('expected frames: ', self.expected_frames)
        for i in range(len(x_samples)):
            x = x_samples[i]
            frames = x.shape[0]
            if frames > self.expected_frames:
                x = x[0:self.expected_frames, :]
                x_samples[i] = x
            elif frames < self.expected_frames:
                temp = np.zeros(shape=(self.expected_frames, x.shape[1]))
                temp[0:frames, :] = x
                x_samples[i] = temp
        for y in y_samples:
            if y not in self.labels:
                self.labels[y] = len(self.labels)
        print(self.labels)
        for i in range(len(y_samples)):
            y_samples[i] = self.labels[y_samples[i]]

        self.nb_classes = len(self.labels)

        y_samples = np_utils.to_categorical(y_samples, self.nb_classes)

        config = dict()
        config['labels'] = self.labels
        config['nb_classes'] = self.nb_classes
        config['num_input_tokens'] = self.num_input_tokens
        config['expected_frames'] = self.expected_frames
        config['vgg16_include_top'] = self.vgg16_include_top

        self.config = config

        np.save(config_file_path, config)

        model = self.create_model()
        open(architecture_file_path, 'w').write(model.to_json())

        Xtrain, Xtest, Ytrain, Ytest = train_test_split(x_samples, y_samples, test_size=test_size,
                                                        random_state=random_state)

        train_gen = generate_batch(Xtrain, Ytrain)
        test_gen = generate_batch(Xtest, Ytest)

        train_num_batches = len(Xtrain) // BATCH_SIZE
        test_num_batches = len(Xtest) // BATCH_SIZE

        checkpoint = ModelCheckpoint(filepath=weight_file_path, save_best_only=True)
        history = model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                      epochs=NUM_EPOCHS,
                                      verbose=1, validation_data=test_gen, validation_steps=test_num_batches,
                                      callbacks=[checkpoint])
        model.save_weights(weight_file_path)

        return history


class VGG16LSTMVideoClassifier(object):
    model_name = 'vgg16-lstm'
    
    def __init__(self):
        self.num_input_tokens = None
        self.nb_classes = None
        self.labels = None
        self.labels_idx2word = None
        self.model = None
        self.vgg16_model = None
        self.expected_frames = None
        self.vgg16_include_top = None
        self.config = None
        
    @staticmethod
    def get_config_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-config.npy'
        else:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-hi-dim-config.npy'

    @staticmethod
    def get_weight_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-weights.h5'
        else:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-hi-dim-weights.h5'

    @staticmethod
    def get_architecture_file_path(model_dir_path, vgg16_include_top=None):
        if vgg16_include_top is None:
            vgg16_include_top = True
        if vgg16_include_top:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-architecture.json'
        else:
            return model_dir_path + '/' + VGG16LSTMVideoClassifier.model_name + '-hi-dim-architecture.json'

    def create_model(self):
        model = Sequential()

        model.add(
            LSTM(units=HIDDEN_UNITS, input_shape=(None, self.num_input_tokens), return_sequences=False, dropout=0.5))
        model.add(Dense(512, activation='relu'))
        model.add(Dropout(0.5))
        model.add(Dense(self.nb_classes))
        model.add(Activation('softmax'))

        model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])
        return model

    def load_model(self, config_file_path, weight_file_path):

        config = np.load(config_file_path).item()
        self.num_input_tokens = config['num_input_tokens']
        self.nb_classes = config['nb_classes']
        self.labels = config['labels']
        self.expected_frames = config['expected_frames']
        self.vgg16_include_top = config['vgg16_include_top']
        self.labels_idx2word = dict([(idx, word) for word, idx in self.labels.items()])

        self.model = self.create_model()
        self.model.load_weights(weight_file_path)

        vgg16_model = VGG16(include_top=self.vgg16_include_top, weights='imagenet')
        vgg16_model.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
        self.vgg16_model = vgg16_model

    def predict(self, video_file_path):
        x = extract_vgg16_features_live(self.vgg16_model, video_file_path)
        frames = x.shape[0]
        if frames > self.expected_frames:
            x = x[0:self.expected_frames, :]
        elif frames < self.expected_frames:
            temp = np.zeros(shape=(self.expected_frames, x.shape[1]))
            temp[0:frames, :] = x
            x = temp
        predicted_class = np.argmax(self.model.predict(np.array([x]))[0])
        predicted_label = self.labels_idx2word[predicted_class]
        return predicted_label

    def fit(self, data_dir_path, model_dir_path, vgg16_include_top=True, data_set_name='UCF-101', test_size=0.3, random_state=42):
        self.vgg16_include_top = vgg16_include_top

        config_file_path = self.get_config_file_path(model_dir_path, vgg16_include_top)
        weight_file_path = self.get_weight_file_path(model_dir_path, vgg16_include_top)
        architecture_file_path = self.get_architecture_file_path(model_dir_path, vgg16_include_top)

        vgg16_model = VGG16(include_top=self.vgg16_include_top, weights='imagenet')
        vgg16_model.compile(optimizer=SGD(), loss='categorical_crossentropy', metrics=['accuracy'])
        self.vgg16_model = vgg16_model

        feature_dir_name = data_set_name + '-VGG16-Features'
        if not vgg16_include_top:
            feature_dir_name = data_set_name + '-VGG16-HiDimFeatures'
        max_frames = 0
        self.labels = dict()
        x_samples, y_samples = scan_and_extract_vgg16_features(data_dir_path,
                                                               output_dir_path=feature_dir_name,
                                                               model=self.vgg16_model,
                                                               data_set_name=data_set_name)
        self.num_input_tokens = x_samples[0].shape[1]
        frames_list = []
        for x in x_samples:
            frames = x.shape[0]
            frames_list.append(frames)
            max_frames = max(frames, max_frames)
            self.expected_frames = int(np.mean(frames_list))
        print('max frames: ', max_frames)
        print('expected frames: ', self.expected_frames)
        for i in range(len(x_samples)):
            x = x_samples[i]
            frames = x.shape[0]
            print(x.shape)
            if frames > self.expected_frames:
                x = x[0:self.expected_frames, :]
                x_samples[i] = x
            elif frames < self.expected_frames:
                temp = np.zeros(shape=(self.expected_frames, x.shape[1]))
                temp[0:frames, :] = x
                x_samples[i] = temp
        for y in y_samples:
            if y not in self.labels:
                self.labels[y] = len(self.labels)
        print(self.labels)
        for i in range(len(y_samples)):
            y_samples[i] = self.labels[y_samples[i]]

        self.nb_classes = len(self.labels)

        y_samples = np_utils.to_categorical(y_samples, self.nb_classes)

        config = dict()
        config['labels'] = self.labels
        config['nb_classes'] = self.nb_classes
        config['num_input_tokens'] = self.num_input_tokens
        config['expected_frames'] = self.expected_frames
        config['vgg16_include_top'] = self.vgg16_include_top
        self.config = config

        np.save(config_file_path, config)

        model = self.create_model()
        open(architecture_file_path, 'w').write(model.to_json())

        Xtrain, Xtest, Ytrain, Ytest = train_test_split(x_samples, y_samples, test_size=test_size,
                                                        random_state=random_state)

        train_gen = generate_batch(Xtrain, Ytrain)
        test_gen = generate_batch(Xtest, Ytest)

        train_num_batches = len(Xtrain) // BATCH_SIZE
        test_num_batches = len(Xtest) // BATCH_SIZE

        checkpoint = ModelCheckpoint(filepath=weight_file_path, save_best_only=True)
        history = model.fit_generator(generator=train_gen, steps_per_epoch=train_num_batches,
                                      epochs=NUM_EPOCHS,
                                      verbose=1, validation_data=test_gen, validation_steps=test_num_batches,
                                      callbacks=[checkpoint])
        model.save_weights(weight_file_path)

        return history

# %%
#3D CNN to be implemented
#Mansoor Roomi Paper to be followed for comparison
#https://github.com/kcct-fujimotolab/3DCNN.git
#https://thinkingneuron.com/face-recognition-using-deep-learning-cnn-in-python/
