# %%
# !git clone https://github.com/temur-kh/video-classification-cv.git
# Out:
# Cloning into 'video-classification-cv'...
# remote: Enumerating objects: 106, done.
# remote: Counting objects: 100% (106/106), done.
# remote: Compressing objects: 100% (82/82), done.
# remote: Total 106 (delta 58), reused 58 (delta 22), pack-reused 0
# Receiving objects: 100% (106/106), 2.30 MiB | 42.81 MiB/s, done.
# Resolving deltas: 100% (58/58), done.

# %%
# %cd/content/video-classification-cv/
# Out:
# /content/video-classification-cv

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 829kB 21.1MB/s
# ...
#      |████████████████████████████████| 14.5MB 271kB/s
# ...
#      |████████████████████████████████| 49.4MB 89kB/s
# ...
#      |████████████████████████████████| 10.5MB 48.6MB/s
# ...
#      |████████████████████████████████| 2.2MB 35.9MB/s
# ...
#      |████████████████████████████████| 512kB 39.7MB/s
# ...
#      |████████████████████████████████| 748.8MB 22kB/s
# ...
#      |████████████████████████████████| 5.9MB 36.7MB/s
# ...
#      |████████████████████████████████| 71kB 10.4MB/s
# ...
#   Created wheel for future: filename=future-0.18.2-cp37-none-any.whl size=491058 sha256=50a003b6b78a27e2967cb4deef5565496f06463aae5df9b620be73158a9726c5
#   Stored in directory: /root/.cache/pip/wheels/8b/99/a0/81daf51dcd359a9377b110a8a886b3895921802d2fc1b2397e
# Successfully built future
# ERROR: torchtext 0.9.1 has requirement torch==1.8.1, but you'll have torch 1.6.0 which is incompatible.
# ...

# %%
# !wget --no-check-certificate "https://www.crcv.ucf.edu/data/UCF50.rar"
# !unrar e UCF50.rar /content/data/videos/
# Out:
# Streaming output truncated to the last 5000 lines.
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
#   OK
# ...

# %%
# !python train.py
# Out:
# Creating model...
# Downloading: "https://download.pytorch.org/models/resnet18-5c106cde.pth" to /root/.cache/torch/hub/checkpoints/resnet18-5c106cde.pth
# 100% 44.7M/44.7M [00:00<00:00, 175MB/s]
# Reading data...
# 4790it [00:00, 242211.49it/s]
# 4790it [00:00, 418539.15it/s]
# Ready for training...
# training...:   0% 0/282 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "train.py", line 182, in <module>
#     sys.exit(main(args))
#   File "train.py", line 149, in main
#     train_loss = train(model, train_dataloader, criterion, optimizer, device=device)
#   File "train.py", line 49, in train
#     for inputs, labels in tqdm.tqdm(loader, total=len(loader), desc="training...", position=0, leave=True):
#   File "/usr/local/lib/python3.7/dist-packages/tqdm/std.py", line 1130, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 363, in __next__
#     data = self._next_data()
# ...
